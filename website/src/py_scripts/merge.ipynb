# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('/Users/pulkith/Downloads/patients.csv')
df2 = pd.read_csv('/Users/pulkith/Downloads/mebb.csv')

# %%
dfm = pd.merge(df1, df2, on='subject_id', how='inner')
dfm
# Out:
#       subject_id gender  anchor_age  anchor_year anchor_year_group  \
# 0       10000032      F          52         2180       2014 - 2016
# 1       10000032      F          52         2180       2014 - 2016
# 2       10000032      F          52         2180       2014 - 2016
# 3       10000032      F          52         2180       2014 - 2016
# 4       10000032      F          52         2180       2014 - 2016
# ...          ...    ...         ...          ...               ...
# 1994    10004733      M          51         2174       2014 - 2016
# 1995    10004733      M          51         2174       2014 - 2016
# 1996    10004733      M          51         2174       2014 - 2016
# 1997    10004733      M          51         2174       2014 - 2016
# 1998    10004749      F          32         2127       2011 - 2013
#
#              dod  microevent_id     hadm_id  micro_specimen_id  \
# 0     2180-09-09              1         NaN             636109
# ...

# %%
dfm.to_csv('../../public/patient_store.csv', index=False)
